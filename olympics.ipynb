# %%
import pandas as pd

# %%
s=pd.read_csv("D:/summer.csv")

# %%
gold=s[s['Medal']=="Gold"]
sport=[]
for i in gold['Sport'].unique():sport.append([i,len(gold[gold['Sport']==i])])
sport=pd.DataFrame(sport,columns=["Sport","Gold"])
sport=sport.sort_values(by ="Gold",ascending=False).head()
print(sport,'\n')
sport.plot(x="Sport",y="Gold",kind="bar",figsize=(7,5))
# Out:
#          Sport  Gold
# 0     Aquatics  1421
# 1    Athletics  1215
# 17      Rowing   890
# 4   Gymnastics   820
# 3      Fencing   552
# <AxesSubplot:xlabel='Sport'>

# %%
sport1=[]
for i in s['Sport'].unique():sport1.append([i,len(s[s['Sport']==i])])
sport1=pd.DataFrame(sport1,columns=["Sport","Medal"])
sport1=sport1.sort_values(by="Medal",ascending=False).head()
print(sport1,'\n')
sport1.plot(x="Sport",y="Medal",kind="bar",figsize=(7,5))
# Out:
#          Sport  Medal
# 0     Aquatics   4170
# 1    Athletics   3638
# 17      Rowing   2667
# 4   Gymnastics   2307
# 3      Fencing   1613
# <AxesSubplot:xlabel='Sport'>

# %%
player=[]
for p in s['Athlete'].unique():player.append([p,len(s[s['Athlete']==p])])
player=pd.DataFrame(player,columns=["Athlete","Medal"])
player=player.sort_values(by= "Medal",ascending = False).head()
print(player,'\n')
player.plot(x="Athlete",y="Medal",kind="bar",figsize=(7,5))
# Out:
#                     Athlete  Medal
# 18640       PHELPS, Michael     22
# 7197       LATYNINA, Larisa     18
# 9948     ANDRIANOV, Nikolay     15
# 6591           ONO, Takashi     13
# 5103   MANGIAROTTI, Edoardo     13
# <AxesSubplot:xlabel='Athlete'>

# %%
g=s[s['Medal']=="Gold"]
player1=[]
for pl in g['Athlete'].unique():player1.append([pl,len(g[g['Athlete']==pl])])
player1=pd.DataFrame(player1,columns=["Athlete","Gold"])
player1=player1.sort_values(by="Gold",ascending=False).head()
print(player1,'\n')
player1.plot(x="Athlete",y="Gold",kind="bar",figsize=(7,5))
# Out:
#                Athlete  Gold
# 6851   PHELPS, Michael    18
# 3320       SPITZ, Mark     9
# 2714  LATYNINA, Larisa     9
# 4630       LEWIS, Carl     9
# 907       NURMI, Paavo     9
# <AxesSubplot:xlabel='Athlete'>

# %%
ind=s[s['Country']=="IND"]
g=ind[ind["Medal"]=="Gold"]
y=[]
for i in g["Year"].unique():y.append(i)
print("In",y[0],"India won its first Gold Medal in Summer Olympics .")
# Out:
# In 1928 India won its first Gold Medal in Summer Olympics .

# %%
e=[]
for i in s['Event'].unique():e.append([i,len(s[s['Event']==i])])
e=pd.DataFrame(e,columns=["Events","Number of Players"])
e=e.sort_values(by="Number of Players",ascending=False).head()
print(e,'\n')
e.plot(x="Events",y="Number of Players",kind="bar",figsize=(7,5))
# Out:
#                Events  Number of Players
# 80           Football               1497
# 176            Hockey               1422
# 138  Team Competition               1147
# 327        Basketball               1012
# 337          Handball                973
# <AxesSubplot:xlabel='Events'>

# %%
f=s[s['Gender']=="Women"]
g_f=f[f["Medal"]=="Gold"]
n=[]
for i in g_f["Sport"].unique():n.append([i,len(g_f[g_f["Sport"]==i])])
n=pd.DataFrame(n,columns=["Sport","Number of Players"])
n=n.sort_values(by="Number of Players",ascending=False).head()
print(n,'\n')
n.plot(x="Sport",y="Number of Players",kind="bar", figsize=(7,5))
# Out:
#          Sport  Number of Players
# 4     Aquatics                589
# 7    Athletics                389
# 8   Gymnastics                268
# 14      Rowing                217
# 11  Volleyball                166
# <AxesSubplot:xlabel='Sport'>
